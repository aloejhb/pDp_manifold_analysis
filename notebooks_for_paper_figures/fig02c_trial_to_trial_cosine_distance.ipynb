# %%
import pandas as pd
from catrace.dataset import load_dataset_config

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
rcParams['pdf.fonttype'] = 42  # Use TrueType fonts
rcParams['axes.linewidth'] = 0.5
rcParams['xtick.major.width'] = 0.5
rcParams['ytick.major.width'] = 0.5
rcParams['savefig.dpi'] = 300  # Ensure a high resolution

# %%
ob_dsconfig = load_dataset_config('../dataset_configs/juvenile_dataset_OB_t7.json')
dp_dsconfig = load_dataset_config('../dataset_configs/juvenile_dataset_t7.json')

# %%
from os.path import join as pjoin
regions = ['OB', 'Dp']
configs = [ob_dsconfig, dp_dsconfig]
metric = 'cosine'
window = [38, 63]#[37, 52]
window_tag = f'window_{window[0]}to{window[1]}'
region_dfs = {region: pd.read_pickle(pjoin(dsconfig.processed_trace_dir, metric, window_tag, 'cross_trial_similarity.pkl')) for region, dsconfig in zip(regions, configs)}
cross_trial_dff = pd.concat(region_dfs.values(), keys=region_dfs.keys(), names=['region', 'fish_id', 'condition'])
cross_trial_dff
# Out:
# odor                                             Phe       Phe       Phe  \
# region fish_id                   condition
# OB     2021-07-15-DpOBEM-N2_OB   naive      0.035013  0.035138  0.031947
#        2021-07-16-DpOBEM-N3_OB   naive      0.033950  0.042504  0.040100
#        2021-12-10-DpOBEM-N4_OB   naive      0.032050  0.035379  0.028582
#        2021-12-31-DpOBEM-N7_OB   naive      0.023314  0.035133  0.029420
#        2022-02-13-DpOBEM-N10_OB  naive      0.021366  0.023936  0.026329
# ...                                              ...       ...       ...
# Dp     2021-11-11-DpOBEM-JH23_Dp phe-trp    0.245631  0.253135  0.225521
#        2021-11-14-DpOBEM-JH23_Dp phe-trp    0.310969  0.412747  0.371826
#        2021-11-24-DpOBEM-JH24_Dp phe-trp    0.228173  0.286030  0.285090
#        2021-11-27-DpOBEM-JH24_Dp phe-trp    0.246682  0.296750  0.256860
#        2021-11-26-DpOBEM-JH24_Dp phe-trp    0.156866  0.301865  0.253712
#
# odor                                             Arg       Arg       Arg  \
# region fish_id                   condition
# OB     2021-07-15-DpOBEM-N2_OB   naive      0.024523  0.030134  0.026093
#        2021-07-16-DpOBEM-N3_OB   naive      0.024173  0.029676  0.029769
#        2021-12-10-DpOBEM-N4_OB   naive      0.035180  0.034820  0.032401
#        2021-12-31-DpOBEM-N7_OB   naive      0.038807  0.042307  0.036475
#        2022-02-13-DpOBEM-N10_OB  naive      0.037648  0.056620  0.041790
# ...                                              ...       ...       ...
# Dp     2021-11-11-DpOBEM-JH23_Dp phe-trp    0.166646  0.190644  0.162744
#        2021-11-14-DpOBEM-JH23_Dp phe-trp    0.285358  0.292987  0.313875
#        2021-11-24-DpOBEM-JH24_Dp phe-trp    0.239940  0.246494  0.235874
#        2021-11-27-DpOBEM-JH24_Dp phe-trp    0.252634  0.275034  0.214959
#        2021-11-26-DpOBEM-JH24_Dp phe-trp    0.155271  0.207489  0.195337
#
# odor                                             Trp       Trp       Trp  \
# region fish_id                   condition
# OB     2021-07-15-DpOBEM-N2_OB   naive      0.045439  0.043467  0.037773
#        2021-07-16-DpOBEM-N3_OB   naive      0.047667  0.056360  0.042128
#        2021-12-10-DpOBEM-N4_OB   naive      0.026427  0.030020  0.029890
#        2021-12-31-DpOBEM-N7_OB   naive      0.029723  0.038311  0.033654
#        2022-02-13-DpOBEM-N10_OB  naive      0.030070  0.036533  0.039617
# ...                                              ...       ...       ...
# Dp     2021-11-11-DpOBEM-JH23_Dp phe-trp    0.350882  0.473146  0.426495
#        2021-11-14-DpOBEM-JH23_Dp phe-trp    0.370512  0.485301  0.419014
#        2021-11-24-DpOBEM-JH24_Dp phe-trp    0.335971  0.418414  0.401728
#        2021-11-27-DpOBEM-JH24_Dp phe-trp    0.331376  0.328161  0.316205
#        2021-11-26-DpOBEM-JH24_Dp phe-trp    0.180616  0.302710  0.252267
#
# [62 rows x 18 columns]

# %%
from catrace.visualize import PlotBoxplotParams, PlotBoxplotMultiOdorCondParams
from catrace.cross_trial import process_and_plot_cross_trial_similarity
params = PlotBoxplotMultiOdorCondParams
odor_keys = ['aa', 'ba'] # stimuli
odor_keys = [f'odors_{key}' for key in odor_keys]

paper_fig_dir = '../figures'
from catrace.for_paper import (save_figure_for_paper, save_stats_json)

dataset_name = 'juvenile'

params = PlotBoxplotMultiOdorCondParams(
        figsize=(2.2, 1.42),
        label_fontsize=6,
        legend_fontsize=5,
        show_ns=True,
        mean_marker_size=1,
        pvalue_marker_xoffset=0.05,
        box_linewidth=1,
        strip_alpha=0.8,
        strip_size=0.5,
        pvalue_bar_linewidth=1,
        pvalue_marker_fontsize=5,
)

fig, test_results, multi_df = process_and_plot_cross_trial_similarity(cross_trial_dff, dp_dsconfig, odor_keys, region='Dp', params=params)
ax = fig.get_axes()[0]
ax = fig.get_axes()[0]
ax.set_ylim((0, 0.68))
ylabel = ax.get_ylabel()
if ylabel=='cosine':
    new_ylabel = 'Trial-to-trial cosine distance'
else:
    new_ylabel = ylabel
ax.set_ylabel(new_ylabel, fontsize=6)
# Remove legend
if ax.get_legend() is not None:
     ax.get_legend().remove()

xlabel_dict = {'odors_aa': 'AA', 'odors_ba': 'BA'}
xlabels = ax.get_xticklabels()
new_xlabels = [xlabel_dict[label.get_text()] for label in xlabels]
ax.set_xticklabels(new_xlabels)

fig_name = fig_name = f'{dataset_name}_trained_cross_trial_similarity'
# save_figure_for_paper(fig, fig_name, paper_fig_dir)
# save_stats_json(test_results, fig_name, paper_fig_dir, tuple_key_to_str=True)
# Out:
# C:\Users\hubob\AppData\Local\Temp\ipykernel_912\333346857.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_xlabels)

# %%
from catrace.stats import format_test_results_multi_odor_two_cond
sentence = format_test_results_multi_odor_two_cond(test_results)
sentence = sentence.replace('odors_aa', 'amino acids').replace('odors_ba', 'bile acids')
print(sentence)
# Out:
# For amino acids, Comparing naive (mean = 0.270 ± 0.0758, n = 54) vs trained (mean = 0.257 ± 0.0691, n = 225): Mann–Whitney U test, U = 6755.00, P = 0.202. For bile acids, Comparing naive (mean = 0.32 ± 0.0596, n = 54) vs trained (mean = 0.33 ± 0.0763, n = 225): Mann–Whitney U test, U = 5480.00, P = 0.264.
